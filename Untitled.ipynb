# %%
# Complex Assignment

 ## Declare a complex number and store it in a variable.
### Check the type and print the id of the same.


a = 20+30j
 
print(a, type(a))



a=20+30j

print (id(a))



# Arithmetic Operations on complex number
### Take two different complex numbers.
### Store them in two different variables.
### Do below operations on them:-
### Find sum of both numbers



a = 20+30j
b = 30+10j
 
print(a+b)

### Find difference between them


a = 40+30j
b = 30+10j

print(a-b)

### Find the product of both numbers.

a = 40+30j
b = 30+10j
 
print(a*b)


### Find value after dividing first num with second number

a = 40+30j
b = 30+10j

print (a/b)

### Find the result of the first num to the power of the second number.



a = 10
b = 5

print(pow(a,b))



 ### Comparison Operation not applicable between instance of complex values.


a = 40+30j
b = 30+10j

print (a>b) 

### Object reusability concept is not applicable on complex number



a = 40+30j
b = 30+10j
 
print(a is b)

    

 ## Equality Operator
### Take two different complex numbers.
### Store them in two different variables.
### Equate them using equality operators (==, !=)
### Observe the output(return type should be boolean)


a = 40+30j
b = 30+10j
 
print( a==b)

a = 40+30j
b = 30+10j
 
print( a!=b)

## Logical operators
### Observe the output of below code
### Cross check the output manually

a=(10+20j)
b= (20+30j)

print(a and b)
                            



a=0.0j
b=20+30j

print (0+0j and 20+30j)

a=(20+30j)
b=(0+0j)

print (20+30j and 0+0j)

a=(0+0j)
b=(0+0j)

print(0+0j and 0+0j) 

a=(10+20j)
b=(20+30j)

print (10+20j or 20+30j)

a= 0+0j
b= 20+30j
print(0+0j or 20+30j)

a= 20+30j
b=0+0j


print(20+30j or 0+0j) 

a= 0+0j
b= 0+0j


print(0+0j or 0+0j) 

a= 10+20j

print(not 10+20j) 

a=0+0j

print(not 0+0j) #True



# What is the output of the expression inside the print statement.
Cross check before running the program.


a = 10+20j
b = 10+20j
print(a is b) 
print(a is not b)


a = ('2.7' in 'Python2.7.8')

print('2.7' in 'Python2.7.8')


a=(10+20j in [10,10.20,10+20j,'Python'])



print(10+20j in [10,10.20,10+20j,'Python'])



a=(10+20j in (10,10.20,10+20j,'Python'))

print(10+20j in (10,10.20,10+20j,'Python'))



a=(30+40j in {1,20.30,30+40j})


print(30+40j in {1,20.30,30+40j})

a=(30+40j in {1:100, 2.3:200, 30+40j:300})


print(30+40j in {1:100, 2.3:200, 30+40j:300})

a=(10 in range(20))

print(10 in range(20))

# BOOLEAN ASSIGNMENT

## Declare a boolean value and store it in a variable.
## Check the type and print the id of the same.


a=True
b=False
print(a,type(a))
print(b,type(b))

a=True
b=False


print (id(a)) 
print (id(b))

# Take one boolean value between 0 - 256.
### Assign it to two different variables.
### Check the id of both the variables. It should come the same. Check why?

a=True
b=True

print (bool,id(a)) 
print (bool,id(b))
print (a is b)

 ## Arithmetic Operations on boolean data
### Take two different boolean values.
### Store them in two different variables.

### Find sum of both value

a=True
b=True

print(a+b)

a=True
b=False

print(a+b)

### Find difference between them

a=True
b=False

print(a - b)

### Find the product of both.

a=True
b=True

print(a * b)

### Find value after dividing first value with second value

a=bool(0)
b=bool(10)
print (a/b)

a=bool(1)
b=bool(10)
print (a/b)

### Find the remainder after dividing first value with second value

a=bool(15)
b=bool(6)

print(a / b)

### Find the quotient after dividing first value with second value

a=bool(0)
b=bool(17)

print(a // b)

a=bool(45)
b=bool(2)

print(a // b)

### Find the result of first value to the power of second value.

a=bool(10)
b=bool(6)

print (a ** b)

## Comparison Operators on boolean valTake two different boolean values.Store them in two    different variables.Do below operations on them:-
 ### Compare these two values with below operator:-
 ### Greater than, '>'
 ### less than, '<'
### Greater than or equal to, '>='
 ### Less than or equal to, '<='
### Observe their output(return type should be boolean.

a=45
b=32

print (a > b)

a=43
b=67

print (a < b)

a=43
b=67

print (a >=b)

a=40
b=69

print (a <=b)

### Equality Operator
### Take two different boolean values.
### Store them in two different variables.
### Equate them using equality operators (==, !=)
### Observe the output(return type should be boolean)



a = 10
b = 76


print(a == b)

a = 67
b = 55


print(a != b)

### Logical operators
###  Observe the output of below code
### Cross check the output manually


a=True
b=True


print(True and True)

a=False
b=True

print(False and True)

a=True
b=False

print(True and False)

a=False
b=False

print(False and False)

a=True
b=True

print(True or True)

a=False
b=True

print(False or True)

a=False
b=False

print(False or False)

a=True
b=False

print(True or False)

a=True

print(not True)



a=False

print(not False)




## Q. Bitwise Operators
### Do below operations on the values provided below:-
### Bitwise and(&) --------------> True, True -------> Output is True
### Bitwise or(|) --------------> True, False -------> Output is True
###  Bitwise(^) --------------> True, False -------> Output is True
### Bitwise left shift ---------> True,2 -------> Output is 4
### Bitwise right shift ---------> True,2 -------> Output is 0


a=True

b=True

print(a & b)

a=True

b=True

print(a | b)

a=True

b=False

print(a ^ b)

a=True

a=print(~a)

 print (True << 2)

print (True >> 2)

### What is the output of expression inside the print statement. 
#### check before running the program.

a = True
b = True
print(a is b) 

a = True
b = True


print(a is not b) 

a = False
b = False
print(a is not b)

### Membership operation in, not in are two membership operators and it returns boolean value

a= True

print(True in [10,10.20,10+20j,'Python', True])



a= False 

print(True in [10,10.20,10+20j,'Python', True])

a= True

print(True in {True:100, False:200, True:300})

a=False

print(False in {True:100, False:200, True:300})


# Float Assignment

### Declare a float value and store it in a variable.
### Check the type and print the id of the same.

a=10.0

print (a,type (a))

a=10.0

print (id (a))

### Arithmetic Operations on float
### Take two different float values.
### Store them in two different variables.
### Find sum of both numbers

a=30.8
b=20.3
print(a+b)

### Find the product of both numbers.

a=20.2
b=40.3
print(a*b)

 ### Find value after dividing first num with second number

a=20.8
b=10.3
print(a/b)

### Find difference between them

a=40.0
b=10.3
print(a-b)

### Find the remainder after dividing first number with second number

a=(15.8)
b=(6.7)

print(a % b)

### Find the quotient after dividing first number with second number

a=(15)
b=(6)

print(a // b)

### Find the result of the first num to the power of the second number.

a=(10.1)
b=(2.0)
print(a ** b)

### Comparison Operators on float
### Take two different float values.
### Store them in two different variables.
### Do below operations on them:-
### Compare these two numbers with below operator:-
### Greater than, '>'
### Smaller than, '<'
### Greater than or equal to, '>='
### Less than or equal to, '<='
### Observe their output(return type should be boolean)

a=33.2
b=21.3

print (a > b)

a=10.2
b=21.3
print (a < b)

a=21.3
b=32.1
print(a>=b)

a=11.3
b=22.1
print(a<=b)

### Equality Operator
### Taketwo different float value.
### store them in two different variables.
### Equate them using equality operators (==, !=)
#### Observe the output(return type should be boolean)

a = 14.3
b = 12.0


print(a != b)

a = 12.3
b = 10.8


print(a == b)

### Logical operators
### Observe the output of below code
#### Cross check the output manually



a=10.20
b=20.30

print(10.20 and 20.30)


a=0.0
b=20.30


print(0.0 and 20.30)

a=(20.30)
b=(0.0)

print(20.30 and 0.0)

a=0.0
b=0.0

print(0.0 and 0.0)

a=10.20
b=20.30

print(10.20 or 20.30)

a = 0.0 
b = 20.30

print(0.0 or 20.30)

a=0.0
b=0.0

print(0.0 or 0.0)

a=10.20

print(not 10.20)

a=0.0

print(not 0.0)

### What is the output of expression inside print statement. Cross check before running the program.



a = 10.20
b = 10.20
print(a is b)


a=10.20
b=256

print (10.20<256)


a = 10.20
b = 10.20

print(a is not b)



### Why the Id of float values are different when the same value is assigned to two different variables
#### ex: a = 10.5 b=10.5. but id will be same if I assign the variable having float i.e. a=c then both a and c's Id are same

a =10.5
b =10.5
print (id,(a))
print (id,(b))

### Bitwise operation is not applicable between instances of float.
#### Why the Id of float values are different when the same value is assigned to two different variables
#### ex: a = 10.5 b=10.5. but id will be same if I assign the variable having float i.e. a=c then both a and c's Id are same


a = 10.5
b = 10.5



## Membership operation
### in, not in are two membership operators and it returns boolean value


print('2.7' in 'Python2.7.8')

print(10.20 in [10,10.20,10+20j,'Python'])


 
print(20.30 in {1,20.30,30+40j}) 



print(2.3 in {1:100, 2.3:200, 30+40j:300})

print(10 in range(20)) 

# Integer Assignment

## Declare an int value and store it in a variable.
### Check the type and print the id of the same.

a= 30

print (a, type(a))

a = 30

print (id(a))

## Take one int value between 0 - 256.
### Assign it to two different variables.Check the id of both the variables. It should come the same. Check why?

a = 20
b = 20
print (id (a))
print (id (b))

## Take one int value either less than -5 or greater than 256.
### Assign it to two different variables.
### Check the id of both the variables. It should come different.Check why?

a= -4
b= -4

print (id (a))
print (id (b))

## Arithmetic Operations on integers
### Take two different integer values.
### Store them in two different variables.
### Do below operations on them:-
### Find sum of both numbers
### Find difference between them
### Find the product of both numbers.
###  Find value after dividing first num with second number
### Find the remainder after dividing first number with second number
### Find the quotient after dividing first number with second number
### Find the result of the first num to the power of the second number.

a = 10
b = 20
print (a+b)

a = 20
b = 10
print (a-b)

a = 40
b = 10
print (a*b)

a = 30
b = 10

print (int(a / b))

a = 40
b = 7

print (a % b)

a = 60
b = 10

print (a // b)

a = 10
b = 3

print (pow(a,b))

##  Comparison Operators on integers
### Take two different integer values.
### Store them in two different variables.
### Do below operations on them:-
### Compare se two numbers with below operator:-
### Greater than, '>'
###  Smaller than, '<'
### Greater than or equal to, '>='
### vLess than or equal to, '<='
### Observe their output(return type should be boolean)

a=30
b=14

print (a > b)

a=30
b=14

print (a < b)

a=20
b=30

print (a <= b)

a=20
b=30

print (a >= b)

## Equality Operator
### Take two different integer values.
### Store them in two different variables.
### Equate them using equality operators (==, !=)
#### Observe the output(return type should be boolean)

a = 20
b = 20
print (a==b)

a = 20
b = 20
print (a!=b)

## Logical operators
### Observe the output of below code
### Cross check the output manually

a = 10
b = 20

print(10 and 20)

a = 0
b = 20

print(0 and 20)


a = 20
b = 0

print(20 and 0)

a = 0
b = 0

print(0 and 0)

a = 10
b = 20

print(10 or 20)

a = 0
b = 20

print(0 or 20)

a = 20
b = 0

print(0 or 20)

a = 20
b = 0


print(20 or 0)

a = 0
b = 0

print(0 or 0)

a = 10

print(not 10)

a = 0

print(not 0)

## Bitwise Operators
### Do below operations on the values provided below:-
### Bitwise and(&) -----------------------------------------> 10, 20
### -------> Output is 0
####  Bitwise or(|) -----------------------------------------> 10, 20
### -------> Output is 30
###  Bitwise(^) -----------------------------------------> 10, 20
### -------> Output is 30
###  Bitwise negation(~) ------------------------------------> 10
### -------> Output is -11
### Bitwise left shift ------------------------------------> 10,2
### -------> Output is 40
### Bitwise right shift ------------------------------------> 10,2
### -------> Output is 2

a = 10 
b = 20
print (a & b)

a = 10 
b = 20
print (a | b)

a = 10 
b = 20
print (a ^ b)

a = 10 
print (~a)

 print (10 << 2)

print (10 >> 2)

## What is the output of expression inside print statement. Cross check before running the program.



a = 10
b = 10
print(a is b)

a = 10
b = 10
print(a is not b)

a = 1000
b = 1000
print(a is b)

a = 1000
b = 1000
print(a is not b)

## Membership operationin, not in are two membership operators and it returns boolean value


print('2' in 'Python2.7.8')

print(10 in [10,10.20,10+20j,'Python'])

print(10  not in  (10,10.20,10+20j,'Python'))

print(10 in (10,10.20,10+20j,'Python'))

print(2 not in {1,2,3})

print(2 in {1,2,3})

print(3 not in {1:100, 2:200, 3:300})

print(3 in {1:100, 2:200, 3:300})

print(10 in range(20))

print(10 not in range(20))

## An integer can be represented in binary, octal or hexadecimal form.
### Declare one binary, one octal and one hexadecimal value and store them in three different variables.
### Convert 9876 to its binary, octal and hexadecimal equivalent and print their corresponding value.



bin(20)

oct(20)

hex(20)

a = 9876

print (bin(9876))

a = 9876

print (hex (9876))



a = 9876

print (oct(9876))


## What will be the output of following:-


a = 0b1010000
print(a)
b = 0o7436
print(b)
c = 0xfade
print(c)

print(bin(80))

print(oct(3870))

print(hex(64222))

print(bin(0b1010000))

print(bin(0xfade))

print(bin(0xfade))

print(oct(0xfade))

print(oct(0o7436))

print(hex(0b1010000))

print(hex(0xfade))

# %%
f = None
for i in range (5):
with open(""data.txt"", ""w"") as f:
if i==2:
break
print(f.closed)
# Out:
#   File "C:\Users\dell\AppData\Local\Temp\ipykernel_16816\3550943122.py", line 3
#     with open(""data.txt"", ""w"") as f:
#     ^
# IndentationError: expected an indented block

# %%
x = 15
if x % 2 == 0:
  print(x, "is even")
else:
  print(x, "is odd")
# Out:
# 15 is odd

# %%
i = 1
while True:
    if i%3 == 0:
        break
    print(i)
 
i + = 1
# Out:
#   File "C:\Users\dell\AppData\Local\Temp\ipykernel_16816\868346622.py", line 7
#     i + = 1
#         ^
# SyntaxError: invalid syntax

# %%
l=[1, 0, 2, 0, 'hello', '', []]
list(filter(bool, l))
# Out:
# [1, 2, 'hello']

# %%
tuple1 = (0, 1, 2, 3) 
tuple1[0] = 4
print(tuple1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16816\3432336895.py in <module>
#       1 tuple1 = (0, 1, 2, 3)
# ----> 2 tuple1[0] = 4
#       3 print(tuple1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
message="learnbay is the best platform"
type(message)
# Out:
# str

# %%
import re
x = 'We just received $10.00 for cookies.'
y = re.findall('\$[0-9.]+',x)
print(y)
# Out:
# ['$10.00']

# %%
a = set([1, 2, 3])
b = set([2, 3, 4])
c = a.intersection(b) # equivalent to c = a & b
a.intersection(b)
c.issubset(a)
# Out:
# True

# %%
s = "learnbay"
for i in s:
  if i == 'b':
      print('Pass executed')
      pass
  print(i)
# Out:
# l
# e
# a
# r
# n
# Pass executed
# b
# a
# y

# %%
def f():
  try:
    return 2
  finally:
    return 1

d = f()
print(d)
# Out:
# 1

# %%
def f(x):
  yield x+1

g=f(2)
print(next(g))
# Out:
# 3

# %%
try:
  if '1' != 1:
    raise "someError"
  else:
    print("NO Error")
except "someError":
  print ("Error")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16816\1824726079.py in <module>
#       2   if '1' != 1:
# ----> 3     raise "someError"
#       4   else:
#
# TypeError: exceptions must derive from BaseException
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16816\1824726079.py in <module>
#       4   else:
#       5     print("NO Error")
# ----> 6 except "someError":
#       7   print ("Error")
#
# TypeError: catching classes that do not inherit from BaseException is not allowed

# %%
f = None
for i in range (5):
with open(""data.txt"", ""w"") as f:
if i==2:
break
print(f.closed)
# Out:
#   File "C:\Users\dell\AppData\Local\Temp\ipykernel_16816\2082351146.py", line 3
#     with open(""data.txt"", ""w"") as f:
#     ^
# IndentationError: expected an indented block

# %%
ord(65)
ord('A')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16816\4063870780.py in <module>
# ----> 1 ord(65)
#       2 ord('A')
#
# TypeError: ord() expected string of length 1, but int found

# %%
.plot(kind="hist")
# Out:
#   File "C:\Users\dell\AppData\Local\Temp\ipykernel_16816\2418321031.py", line 1
#     .plot(kind="hist")
#     ^
# SyntaxError: invalid syntax

# %%
s = "learnbay"
for i in s:
  if i == 'b':
      print('Pass executed')
      pass
  print(i)
# Out:
# l
# e
# a
# r
# n
# Pass executed
# b
# a
# y
